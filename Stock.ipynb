# %%
import yfinance as yf
import pandas as pd

# Set the start and end date
start_date = '2021-07-06'
end_date = '2021-10-04'
ticker=['ACC','ADANIPORTS.NS','ADANIENT.NS','ADANIPOWER.NS','AMBUJACEM.NS','APOLLOHOSP.NS','ARVIND.NS','ASIANPAINT.NS','AUROPHARMA.NS',
'BAJFINANCE.NS','BALKRISIND.NS','BANKBARODA.NS','BANKINDIA.NS', 'BERGEPAINT.NS','BHEL.NS','BAJAJFINSV.NS','BOSCHLTD.NS','CADILAHC.NS',  
'CENTURYTEX.NS','CHOLAFIN.NS','CUMMINSIND.NS','DIVISLAB.NS','DLF.NS','ENGINERSIN.NS','EQUITAS.NS','ESCORTS.NS','FEDERALBNK.NS',
'GODREJCP.NS','GRASIM.NS','HAVELLS.NS','HCLTECH.NS','BSOFT.NS','HDFCBANK.NS','HEXAWARE.NS','HINDPETRO.NS', 
'CANBK.NS','HINDZINC.NS','IDEA','IDFCFIRSTB.NS','CASTROLIND.NS','INDIGO.NS','INDUSINDBK.NS','INFY','IOC.NS','DHFL.NS','ITC',       
'JINDALSTEL.NS','EICHERMOT.NS','JSWSTEEL.NS','JUBLFOOD.NS','JUSTDIAL.NS','KOTAKBANK.NS','EXIDEIND.NS','L&TFH.NS','LUPIN.NS',     
'M&M.NS','GLENMARK.NS','MARICO.NS','MCDOWELL-N.NS','MCX.NS','MOTHERSUMI.NS','MRF.NS','MUTHOOTFIN.NS','NATIONALUM.NS','NCC',       
'ICICIPRULI.NS','NESTLEIND.NS','NTPC.NS','ONGC.NS','PAGEIND.NS','INFRATEL','PFC','PIDILITIND.NS','PNB.NS','RAMCOCEM.NS',  
'RAYMOND.NS','RECLTD.NS','RELCAPITAL.NS','RELIANCE.NS','SAIL','SIEMENS.NS','SRF.NS','SRTRANSFIN.NS','STAR','TATAGLOBAL.NS',
'TATAPOWER.NS','TCS','MGL.NS','TECHM.NS','MINDTREE.NS','TORNTPOWER.NS','UBL.NS','UJJIVAN.NS','UNIONBANK.NS','UPL.NS','VEDL',      
'VOLTAS.NS','WIPRO.NS','YESBANK.NS','AMARAJABAT.NS','NIITLTD.NS', 'RELINFRA.NS','APOLLOTYRE.NS','AXISBANK.NS','TITAN.NS',     
'ASHOKLEY.NS','BAJAJ-AUTO.NS','BATAINDIA.NS','BEL.NS','BHARATFORG.NS','BIOCON.NS','BPCL.NS',      
'BRITANNIA.NS','CESC.NS','CIPLA.NS','COALINDIA.NS','DABUR.NS','DISHTV.NS','GAIL.NS','GMRINFRA.NS','HDFC.NS','HEROMOTOCO.NS','CONCOR.NS',    
'HINDALCO.NS','DRREDDY.NS','HINDUNILVR.NS','IBULHSGFIN.NS','IDBI.NS','IGL.NS','MANAPPURAM.NS','MFSL.NS','M&MFIN.NS','MARUTI.NS','OFSS.NS',      
'NMDC.NS','OIL','POWERGRID.NS','RBLBANK.NS','SHREECEM.NS','SUNPHARMA.NS','TATASTEEL.NS','TATAELXSI.NS','TORNTPHARM.NS','TVSMOTOR.NS',  
'ULTRACEMCO.NS','ZEEL.NS','COLPAL.NS','ICICIBANK.NS','LICHSGFIN.NS','SBIN.NS','BHARTIARTL.NS','LT.NS','NBCC.NS','KAJARIACER.NS','PEL.NS',       
'PETRONET.NS','PVR.NS','TATACHEM.NS','TATAMOTORS.NS','TATAMTRDVR.NS','SUNTV.NS']
data=yf.download(ticker, start_date,end_date)
data

df=data['Close']
df

exc=df.to_excel("data.xlsx")
exv=pd.read_excel("data.xlsx",header=None)
exv
# Out:
# [*********************100%***********************]  161 of 161 completed
#
# 3 Failed downloads:
# - INFRATEL: No data found, symbol may be delisted
# - TATAGLOBAL.NS: No data found, symbol may be delisted
# - HEXAWARE.NS: No data found for this date range, symbol may be delisted
#                     0      1            2              3              4    \
# 0                  Date    ACC  ADANIENT.NS  ADANIPORTS.NS  ADANIPOWER.NS
# 1   2021-07-06 00:00:00  48.54       1414.8          712.7          111.9
# 2   2021-07-07 00:00:00  48.86      1425.65          720.1          109.8
# 3   2021-07-08 00:00:00   48.3       1425.9          711.7         108.75
# 4   2021-07-09 00:00:00  49.26      1431.35          728.5         109.55
# ..                  ...    ...          ...            ...            ...
# 60  2021-09-27 00:00:00  49.63      1531.25         750.25             97
# 61  2021-09-28 00:00:00  49.58       1487.3          738.7             96
# ...
